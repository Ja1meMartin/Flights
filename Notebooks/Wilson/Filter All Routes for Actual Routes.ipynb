# %%
from airport_names import get_all_routes
from collections import deque
old_routes = set(get_all_routes())
new_routes = set()

# %%
"""api = 'ja373863706848344628128972526671'
from skyscanner.skyscanner import FlightsCache
flights_cache_service = FlightsCache(api)"""

# %%
import csv

with open('Fabrication/routes.dat') as routes:
    reader = csv.reader(routes)
    
    for line in reader:
        route = (line[2], line[4])
        if route in old_routes:
            new_routes.add(route)

print(len(old_routes), len(new_routes))
# Out:
# 13695 2766

# %%
print(list(new_routes))
# Out:
# [('AAL', 'AMS'), ('BEG', 'ZRH'), ('SOF', 'STN'), ('UFA', 'LED'), ('BUD', 'CIA'), ('LUX', 'AMS'), ('BUD', 'ARN'), ('VIE', 'MSQ'), ('DUB', 'OTP'), ('FKB', 'TFS'), ('EIN', 'LPA'), ('KBP', 'AMS'), ('VCE', 'LGW'), ('ZRH', 'HAJ'), ('FRA', 'TRN'), ('BUD', 'HAM'), ('BEG', 'MXP'), ('LED', 'FCO'), ('BGY', 'AGP'), ('NCE', 'LHR'), ('BCN', 'WMI'), ('AGP', 'BGO'), ('ZAG', 'FRA'), ('VIE', 'CGN'), ('SVO', 'RIX'), ('MUC', 'WAW'), ('PRG', 'CPH'), ('STN', 'PRG'), ('MLA', 'CDG'), ('BFS', 'ALC'), ('ALC', 'EDI'), ('CDG', 'BFS'), ('MUC', 'STR'), ('MLA', 'DUS'), ('SOF', 'BLQ'), ('WAW', 'KBP'), ('GOA', 'CAG'), ('CDG', 'GOT'), ('SVO', 'TFS'), ('ZRH', 'HAM'), ('CRL', 'BLQ'), ('GOT', 'HEL'), ('BRU', 'DME'), ('CDG', 'SCQ'), ('OSL', 'PSA'), ('TSF', 'CTA'), ('DOK', 'MUC'), ('STR', 'CTA'), ('FRA', 'NUE'), ('LPA', 'LGW'), ('AGP', 'MRS'), ('GLA', 'LGW'), ('MXP', 'TFS'), ('WAW', 'ODS'), ('LTN', 'ALC'), ('CRL', 'OTP'), ('BCN', 'CWL'), ('IST', 'KBP'), ('IST', 'BHX'), ('EMA', 'EGC'), ('EIN', 'ALC'), ('BGY', 'WRO'), ('MXP
# ...
